_ktu', 'gatitos__en_chm', 'gatitos__en_mfe', 'gatitos__en_pcm', 'gatitos__en_nd', 'gatitos__en_se', 'gatitos__en_oc', 'gatitos__en_os', 'gatitos__en_rhg-Latn', 'gatitos__en_rom', 'gatitos__en_skr', 'gatitos__en_shn', 'gatitos__en_ber-Latn', 'gatitos__en_ber', 'gatitos__en_tet', 'gatitos__en_bo', 'gatitos__en_tpi', 'gatitos__en_to', 'gatitos__en_tn', 'gatitos__en_aeb', 'gatitos__en_udm', 'gatitos__en_ve', 'gatitos__en_vec', 'gatitos__en_sah', 'gatitos__en_yua', 'gatitos__en_zza', 'gatitos__en_ace', 'gatitos__en_ach', 'gatitos__en_ady', 'gatitos__en_aa', 'gatitos__en_awa', 'gatitos__en_bug', 'gatitos__en_ce', 'gatitos__en_cv', 'gatitos__en_fa-AF', 'gatitos__en_dyu', 'gatitos__yue_zh-Hant', 'gatitos__zh-Hant_yue', 'gatitos__yue_zh', 'gatitos__zh_yue', 'gatitos__en_yue', 'gatitos__en_arz', 'gatitos__en_cnh', 'gatitos__en_hil', 'gatitos__en_iba', 'gatitos__en_iu', 'gatitos__en_kac', 'gatitos__en_pa-Arab', 'gatitos__en_ayl', 'gatitos__en_mad', 'gatitos__en_mak', 'gatitos__en_ms-Arab', 'gatitos__en_arn', 'gatitos__en_mwr', 'gatitos__en_min', 'gatitos__en_nv', 'gatitos__en_nr', 'gatitos__en_apd', 'gatitos__en_tcy', 'gatitos__en_scn', 'gatitos__en_war', 'gatitos__en_mh', 'gatitos__en_crs', 'gatitos__en_jam', 'gatitos__en_brx', 'gatitos__en_fon', 'gatitos__en_wo', 'gatitos__en_kha', 'gatitos__en_pam', 'gatitos__en_zap', 'gatitos__en_av', 'gatitos__en_ar-MA', 'gatitos__en_mag', 'gatitos__en_crh-Latn', 'gatitos__en_kek', 'gatitos__en_apc', 'gatitos__en_syl', 'gatitos__en_nus', 'gatitos__en_ks-Deva', 'gatitos__en_new', 'gatitos__en_lg', 'gatitos__en_ay', 'gatitos__en_es', 'gatitos__en_as', 'gatitos__en_doi', 'gatitos__en_ckb', 'gatitos__en_ee', 'gatitos__en_gn', 'gatitos__en_qu', 'gatitos__en_gom', 'gatitos__en_ilo', 'gatitos__en_kri', 'gatitos__en_kl', 'gatitos__en_lus', 'gatitos__en_fr', 'gatitos__en_ts', 'gatitos__en_ln', 'gatitos__en_sa', 'gatitos__en_hi', 'gatitos__en_nso', 'gatitos__en_ak', 'gatitos__en_ff', 'gatitos__en_om', 'gatitos__en_bho', 'gatitos__en_mai', 'gatitos__en_bm', 'gatitos__en_ti', 'gatitos__en_dv', 'gatitos__en_mni-Mtei']
configs_smaldoc = [cfg for cfg in configs if cfg.startswith('smoldoc')]

ds = load_dataset("google/smol", configs_smaldoc[0])

ds

# %%
print(f"Available configurations in SMOLDOC: {len(configs_smaldoc)}")

# %% [markdown]
# We can look at one of the rows of training data with

# %%
ds['train'][0]

# %% [markdown]
# We load all of them with (such that they are cached)

# %%
for c in configs_smaldoc:
    print(f"Loading config: {c}")
    ds_t = load_dataset("google/smol", c)

# %%
from utils import get_smoldoc_factuality
import pandas as pd

fact_dict = get_smoldoc_factuality(data_dir="data")
fact_ds = pd.DataFrame(fact_dict).transpose()
fact_ds.head()

# %%
df = pd.DataFrame(ds['train'])
df.head()

# %%
df.join(fact_ds, on='id')
